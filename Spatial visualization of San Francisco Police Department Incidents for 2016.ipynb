# %% [markdown]
# # Spatial visualization of San Francisco Police Department Incidents for 2016

# %% [markdown]
# ## Objectives
# Visualize geospatial data with Folium
#
# ## Introduction
# In this notebook, we will create maps for different objectives. To do that, we will part ways with Matplotlib and work with another Python visualization library, namely Folium. What is nice about Folium is that it was developed for the sole purpose of visualizing geospatial data.
#
# ## Tool Kit
# This Notebook heavily relies on pandas and Numpy for data wrangling, analysis, and visualization. The primary plotting library we will explore in this lab is Folium.
#
# ## Data Set
# San Francisco Police Department Incidents for the year 2016 - Police Department Incidents from San Francisco public data portal. Incidents derived from San Francisco Police Department (SFPD) Crime Incident Reporting system. Updated daily, showing data for the entire year of 2016. Address and location has been anonymized by moving to mid-block or to an intersection.
#
# https://data.sfgov.org/Public-Safety/Police-Department-Incident-Reports-Historical-2003/tmnf-yvry
#
# This dataset is available from 2003 to May 2018 - We will filter the data for 2016 only

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import folium

# %% [markdown]
# #### Installing Folium

# %%
#!conda install -c conda-forge folium=0.5.0 --yes
#print('Folium installed and imported!')

# %% [markdown]
# ### Initializing Folium

# %% [markdown]
# Here we will initilize Folium and see the entire map of the world.

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_b13cd2d17c939b809c6f52ed2936b352 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b13cd2d17c939b809c6f52ed2936b352&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_b13cd2d17c939b809c6f52ed2936b352 = L.map(
#                                   &#x27;map_b13cd2d17c939b809c6f52ed2936b352&#x27;,
#                                   {center: [0,0],
#                                   zoom: 1,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_46aff337ad3cb23b9523da9c81f4c715 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_b13cd2d17c939b809c6f52ed2936b352);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we will focus the map to any city - Boston

# %%
# SF Map
bos_map = folium.Map(location=[42.3601, -71.0589], zoom_start=12)

# display world map
bos_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_e905e3d138c29627891bc9a5f20910c4 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e905e3d138c29627891bc9a5f20910c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_e905e3d138c29627891bc9a5f20910c4 = L.map(
#                                   &#x27;map_e905e3d138c29627891bc9a5f20910c4&#x27;,
#                                   {center: [42.3601,-71.0589],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_0cbac53279fe9906349d16035c86ea4b = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_e905e3d138c29627891bc9a5f20910c4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can also change the style of the maps - Shown Below

# %%
# SF Map
bos_map = folium.Map(location=[42.3601, -71.0589], zoom_start=12,tiles='Stamen Toner')

# display world map
bos_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_708d4e00e50b2f57477d2243ff962597 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_708d4e00e50b2f57477d2243ff962597&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_708d4e00e50b2f57477d2243ff962597 = L.map(
#                                   &#x27;map_708d4e00e50b2f57477d2243ff962597&#x27;,
#                                   {center: [42.3601,-71.0589],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_c8b9660b3b8d64ffeab0f286e0bc4bce = L.tileLayer(
#                 &#x27;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_708d4e00e50b2f57477d2243ff962597);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Boston Map
bos_map = folium.Map(location=[42.3601, -71.0589], zoom_start=12,tiles='Stamen Terrain')

# display world map
bos_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_9eb1c4ffd4adfc979f012f7a69f0052c {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9eb1c4ffd4adfc979f012f7a69f0052c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_9eb1c4ffd4adfc979f012f7a69f0052c = L.map(
#                                   &#x27;map_9eb1c4ffd4adfc979f012f7a69f0052c&#x27;,
#                                   {center: [42.3601,-71.0589],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_c0ec959bdbc1ece9202dc70110e59e6e = L.tileLayer(
#                 &#x27;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_9eb1c4ffd4adfc979f012f7a69f0052c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Loading Data Set

# %%
df_incidents=pd.read_csv('/Users/mianmibrahim/Documents/Untitled Folder/Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv')
df_incidents.head(10)
# Out:
#              PdId  IncidntNum  Incident Code       Category  \
# 0   4133422003074    41334220           3074        ROBBERY
# 1   5118535807021    51185358           7021  VEHICLE THEFT
# 2   4018830907021    40188309           7021  VEHICLE THEFT
# 3  11014543126030   110145431          26030          ARSON
# 4  10108108004134   101081080           4134        ASSAULT
# 5  13027069804134   130270698           4134        ASSAULT
# 6  17063991304134   170639913           4134        ASSAULT
# 7  16020415607020   160204156           7020  VEHICLE THEFT
# 8   6068579904134    60685799           4134        ASSAULT
# 9   5134166327195    51341663          27195       TRESPASS
#
#                        Descript DayOfWeek        Date   Time  PdDistrict  \
# 0         ROBBERY, BODILY FORCE    Monday  11/22/2004  17:50   INGLESIDE
# 1             STOLEN AUTOMOBILE   Tuesday  10/18/2005  20:00        PARK
# 2             STOLEN AUTOMOBILE    Sunday  02/15/2004  02:00    SOUTHERN
# 3                         ARSON    Friday  02/18/2011  05:27   INGLESIDE
# 4                       BATTERY    Sunday  11/21/2010  17:00    SOUTHERN
# 5                       BATTERY   Tuesday  04/02/2013  15:50     TARAVAL
# 6                       BATTERY    Sunday  08/06/2017  18:15    SOUTHERN
# 7  STOLEN AND RECOVERED VEHICLE  Thursday  03/03/2016  19:30     TARAVAL
# 8                       BATTERY  Saturday  06/17/2006  03:00     TARAVAL
# 9                   TRESPASSING    Monday  11/28/2005  16:04  TENDERLOIN
#
#        Resolution  ... Fix It Zones as of 2017-11-06  2 2  \
# 0            NONE  ...                                NaN
# 1            NONE  ...                                NaN
# 2            NONE  ...                                NaN
# 3            NONE  ...                                NaN
# 4            NONE  ...                                NaN
# 5            NONE  ...                                NaN
# 6            NONE  ...                                NaN
# 7            NONE  ...                                NaN
# 8            NONE  ...                                NaN
# 9  ARREST, BOOKED  ...                                NaN
#
#    DELETE - HSOC Zones 2 2  Fix It Zones as of 2018-02-07 2 2  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
# 5                      NaN                                NaN
# 6                      NaN                                NaN
# 7                      NaN                                NaN
# 8                      NaN                                NaN
# 9                      NaN                                NaN
#
#   CBD, BID and GBD Boundaries as of 2017 2 2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
#
#    Areas of Vulnerability, 2016 2 2  Central Market/Tenderloin Boundary 2 2  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               1.0                                     NaN
# 4                               2.0                                     NaN
# 5                               1.0                                     NaN
# 6                               2.0                                     NaN
# 7                               NaN                                     NaN
# 8                               NaN                                     NaN
# 9                               NaN                                     NaN
#
#    Central Market/Tenderloin Boundary Polygon - Updated 2 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    HSOC Zones as of 2018-06-05 2 2  OWED Public Spaces 2 2  Neighborhoods 2
# 0                              NaN                     NaN              NaN
# 1                              NaN                     NaN              NaN
# 2                              NaN                     NaN              NaN
# 3                              NaN                     NaN             94.0
# 4                              NaN                     NaN             32.0
# 5                              NaN                     NaN             44.0
# 6                              NaN                     NaN             32.0
# 7                              NaN                     NaN              NaN
# 8                              NaN                     NaN              NaN
# 9                              NaN                     NaN              NaN
#
# [10 rows x 35 columns]

# %%
df_incidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129525 entries, 0 to 2129524
# Data columns (total 35 columns):
#  #   Column                                                    Dtype
# ---  ------                                                    -----
#  0   PdId                                                      int64
#  1   IncidntNum                                                int64
#  2   Incident Code                                             int64
#  3   Category                                                  object
#  4   Descript                                                  object
#  5   DayOfWeek                                                 object
#  6   Date                                                      object
#  7   Time                                                      object
#  8   PdDistrict                                                object
#  9   Resolution                                                object
#  10  Address                                                   object
#  11  X                                                         float64
#  12  Y                                                         float64
#  13  location                                                  object
#  14  SF Find Neighborhoods 2 2                                 float64
#  15  Current Police Districts 2 2                              float64
#  16  Current Supervisor Districts 2 2                          float64
#  17  Analysis Neighborhoods 2 2                                float64
#  18  DELETE - Fire Prevention Districts 2 2                    float64
#  19  DELETE - Police Districts 2 2                             float64
#  20  DELETE - Supervisor Districts 2 2                         float64
#  21  DELETE - Zip Codes 2 2                                    float64
#  22  DELETE - Neighborhoods 2 2                                float64
#  23  DELETE - 2017 Fix It Zones 2 2                            float64
#  24  Civic Center Harm Reduction Project Boundary 2 2          float64
#  25  Fix It Zones as of 2017-11-06  2 2                        float64
#  26  DELETE - HSOC Zones 2 2                                   float64
#  27  Fix It Zones as of 2018-02-07 2 2                         float64
#  28  CBD, BID and GBD Boundaries as of 2017 2 2                float64
#  29  Areas of Vulnerability, 2016 2 2                          float64
#  30  Central Market/Tenderloin Boundary 2 2                    float64
#  31  Central Market/Tenderloin Boundary Polygon - Updated 2 2  float64
#  32  HSOC Zones as of 2018-06-05 2 2                           float64
#  33  OWED Public Spaces 2 2                                    float64
#  34  Neighborhoods 2                                           float64
# dtypes: float64(23), int64(3), object(9)
# memory usage: 568.6+ MB

# %% [markdown]
# ### Dropping Columns
#
# From the Data Set Above, we can see we have to remove un necessary columns which are not required for mapping. We will keep the following 13 columns in our dataset
#
# **PdId**: The police department ID
#
# **IncidntNum**: Incident Number
#
# **Category**: Category of crime or incident
#
# **Descript**: Description of the crime or incident
#
# **DayOfWeek**: The day of week on which the incident occurred
#
# **Date**: The Date on which the incident occurred
#
# **Time**: The time of day on which the incident occurred
#
# **PdDistrict**: The police department district
#
# **Resolution**: The resolution of the crime in terms whether the perpetrator was arrested or not
#
# **Address**: The closest address to where the incident took place
#
# **X**: The longitude value of the crime location
#
# **Y**: The latitude value of the crime location
#
# **Location**: A tuple of the latitude and the longitude values

# %%
df_incidents=df_incidents.drop(['Incident Code','SF Find Neighborhoods 2 2', 'Current Police Districts 2 2',
       'Current Supervisor Districts 2 2', 'Analysis Neighborhoods 2 2',
       'DELETE - Fire Prevention Districts 2 2',
       'DELETE - Police Districts 2 2', 'DELETE - Supervisor Districts 2 2',
       'DELETE - Zip Codes 2 2', 'DELETE - Neighborhoods 2 2',
       'DELETE - 2017 Fix It Zones 2 2',
       'Civic Center Harm Reduction Project Boundary 2 2',
       'Fix It Zones as of 2017-11-06  2 2', 'DELETE - HSOC Zones 2 2',
       'Fix It Zones as of 2018-02-07 2 2',
       'CBD, BID and GBD Boundaries as of 2017 2 2',
       'Areas of Vulnerability, 2016 2 2',
       'Central Market/Tenderloin Boundary 2 2',
       'Central Market/Tenderloin Boundary Polygon - Updated 2 2',
       'HSOC Zones as of 2018-06-05 2 2', 'OWED Public Spaces 2 2',
       'Neighborhoods 2'], axis=1)

# %%
df_incidents.head()
# Out:
#              PdId  IncidntNum       Category               Descript DayOfWeek  \
# 0   4133422003074    41334220        ROBBERY  ROBBERY, BODILY FORCE    Monday
# 1   5118535807021    51185358  VEHICLE THEFT      STOLEN AUTOMOBILE   Tuesday
# 2   4018830907021    40188309  VEHICLE THEFT      STOLEN AUTOMOBILE    Sunday
# 3  11014543126030   110145431          ARSON                  ARSON    Friday
# 4  10108108004134   101081080        ASSAULT                BATTERY    Sunday
#
#          Date   Time PdDistrict Resolution                 Address  \
# 0  11/22/2004  17:50  INGLESIDE       NONE   GENEVA AV / SANTOS ST
# 1  10/18/2005  20:00       PARK       NONE  TURK ST / STJOSEPHS AV
# 2  02/15/2004  02:00   SOUTHERN       NONE     BRANNAN ST / 1ST ST
# 3  02/18/2011  05:27  INGLESIDE       NONE   0 Block of SANJUAN AV
# 4  11/21/2010  17:00   SOUTHERN       NONE    400 Block of 10TH ST
#
#             X          Y                                      location
# 0 -122.420084  37.708311    POINT (-122.420084075249 37.7083109744362)
# 1 -120.500000  90.000000                POINT (-120.50000000000001 90)
# 2 -120.500000  90.000000                POINT (-120.50000000000001 90)
# 3 -122.436220  37.724377  POINT (-122.43622001281001 37.7243766140428)
# 4 -122.410541  37.770913    POINT (-122.410541166987 37.7709130566165)

# %%
df_incidents.shape
# Out:
# (2129525, 13)

# %% [markdown]
# ### Filtering Dates

# %%
# Filter Rows between dates 1/1/2016 - 12/31/2016

df_incidents['Date'] = pd.to_datetime(df_incidents['Date'], format='%m/%d/%Y')
  
# Filter data between two dates
df_2016 = df_incidents.loc[(df_incidents['Date'] >= '2016-01-01') & (df_incidents['Date'] < '2017-01-01')]

# %%
df_2016.shape
# Out:
# (145994, 13)

# %% [markdown]
# From here, we see that there are around 146K Records in 2016

# %% [markdown]
# ### Mapping Data on Maps

# %% [markdown]
# First we will superimpose crimes on the map using Folium. We will take the first 100 incidents to reduce computational cost

# %%
# Initilizing Maps on Folium

# San Francisco latitude and longitude values
latitude = 37.77
longitude = -122.42

# create map and display it
sf_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# display the map of San Francisco
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_113155b7c69c693ae0c0d5f31f969a7d {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_113155b7c69c693ae0c0d5f31f969a7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_113155b7c69c693ae0c0d5f31f969a7d = L.map(
#                                   &#x27;map_113155b7c69c693ae0c0d5f31f969a7d&#x27;,
#                                   {center: [37.77,-122.42],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_0714f2f96f6e70a44d5521d92694250b = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_113155b7c69c693ae0c0d5f31f969a7d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Taking the first 100 incidents 

limit = 100
df_2016_100 = df_2016.iloc[0:limit, :]

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# %% [markdown]
# #### Visulizing the crimes - 1
#
# In the visulization below, we can see that we located the coordinates of incidents incidents.

# %%
# let's start again with a clean copy of the map of San Francisco

sf_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(df_2016_100.Y, df_2016_100.X):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='red'
        )
    )

# add incidents to map
sf_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_91e4e611f251f0f8c269e71a6141020c {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91e4e611f251f0f8c269e71a6141020c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_91e4e611f251f0f8c269e71a6141020c = L.map(
#                                   &#x27;map_91e4e611f251f0f8c269e71a6141020c&#x27;,
#                                   {center: [37.77,-122.42],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_2df2778313058b8c7c1697b66cd2cc49 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_91e4e611f251f0f8c269e71a6141020c);
#
#
#             var feature_group_7e762a58705c29424a64fccaec112b19 = L.featureGroup(
#                 ).addTo(map_91e4e611f251f0f8c269e71a6141020c);
#
#
#             var circle_marker_425628404e1285ec3589e1478bdd5155 = L.circleMarker(
#                 [37.70796836450968,-122.46354501681948],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(feature_group_7e762a58705c29424a64fccaec112b19);
#
#
#             var circle_marker_86533d085a508635a779d6ed5ef37ee4 = L.circleMarker(
#                 [37.77563367344303,-122.4124473731242],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(feature_group_7e762a58705c29424a64fccaec112b19);
#
#
#             var circle_marker_53328bd09ec75cb55a897fc23786136f = L.circleMarker(
#                 [37.78413995095941,-122.41095524890568],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(feature_group_7e762a58705c29424a64fccaec112b19);
#
#
#             var circle_marker_58d3d16ebcfb3e316fa77625dc8266db = L.circleMarker(
#                 [37.77576787976692,-122.41643219291596],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(feature_group_7e762a58705c29424a64fccaec112b19);
#
#
#             var circle_marker_312e9cb26868d6ac46880b6af0d201f8 = L.circleMarker(
#                 [37.76887083988612,-122.4243784327292],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(feature_group_7e762a58705c29424a64fccaec112b19);
#
#
#             var circle_marker_d4610404537f63af1b67669742b0e920 = L.circleMarker(
#                 [37.77318861617496,-122.4907520910972],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(feature_group_7e762a58705c29424a64fccaec112b19

# %% [markdown]
# #### Visulizing the crimes - 2
#
# If we want to get more details on what sort of crime occured at the location, we can add pop up markers

# %%
# let's start again with a clean copy of the map of San Francisco
sf_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(df_2016_100.Y, df_2016_100.X):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='red'
        )
    )

# add pop-up text to each marker on the map
latitudes = list(df_2016_100.Y)
longitudes = list(df_2016_100.X)
labels = list(df_2016_100.Category)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(sf_map)    
    
# add incidents to map
sf_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1 = L.map(
#                                   &#x27;map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1&#x27;,
#                                   {center: [37.77,-122.42],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_1cdb2b3fe2f5d99372d7ebbeb8a69be0 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1);
#
#
#
#             var marker_361265893d3201b95f8603ea08e6438f = L.marker(
#                 [37.70796836450968,-122.46354501681948],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1);
#
#
#             var popup_cadd466aea2cb479a86ae69d608a67be = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_97bcb20cdd54f3f8020bfe3a17d746b9 = $(&#x27;&lt;div id=&quot;html_97bcb20cdd54f3f8020bfe3a17d746b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VEHICLE THEFT&lt;/div&gt;&#x27;)[0];
#                 popup_cadd466aea2cb479a86ae69d608a67be.setContent(html_97bcb20cdd54f3f8020bfe3a17d746b9);
#
#
#             marker_361265893d3201b95f8603ea08e6438f.bindPopup(popup_cadd466aea2cb479a86ae69d608a67be);
#
#
#
#
#
#             var marker_84144bdbc07e66b58c7c4e30f5563fe1 = L.marker(
#                 [37.77563367344303,-122.4124473731242],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1);
#
#
#             var popup_5711be757e1c30c34c580b722c616b24 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_907a135c17c13b1945f5340a0dea0e89 = $(&#x27;&lt;div id=&quot;html_907a135c17c13b1945f5340a0dea0e89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FRAUD&lt;/div&gt;&#x27;)[0];
#                 popup_5711be757e1c30c34c580b722c616b24.setContent(html_907a135c17c13b1945f5340a0dea0e89);
#
#
#             marker_84144bdbc07e66b58c7c4e30f5563fe1.bindPopup(popup_5711be757e1c30c34c580b722c616b24);
#
#
#
#
#
#             var marker_644bd4c7e23edd6a08fbe9805b71d4b8 = L.marker(
#                 [37.78413995095941,-122.41095524890568],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1);
#
#
#             var popup_72562ca242bed41f3c1534ec913f59e1 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_156e9679c1715dfd6e9195353fbe8b08 = $(&#x27;&lt;div id=&quot;html_156e9679c1715dfd6e9195353fbe8b08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;&#x27;)[0];
#                 popup_72562ca242bed41f3c1534ec913f59e1.setContent(html_156e9679c1715dfd6e9195353fbe8b08);
#
#
#             marker_644bd4c7e23edd6a08fbe9805b71d4b8.bindPopup(popup_72562ca242bed41f3c1534ec913f59e1);
#
#
#
#
#
#             var marker_ae8820581a27f81482a6468c2d267f24 = L.marker(
#                 [37.77576787976692,-122.41643219291596],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1);
#
#
#             var popup_205a40e52526e3ed222f85171d9c05b0 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_fa83cfb5f771fa819d2f3fcf85ef60f8 = $(&#x27;&lt;div id=&quot;html_fa83cfb5f771fa819d2f3fcf85ef60f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;&#x27;)[0];
#                 popup_205a40e52526e3ed222f85171d9c05b0.setContent(html_fa83cfb5f771fa819d2f3fcf85ef60f8);
#
#
#             marker_ae8820581a27f81482a6468c2d267f24.bindPopup(popup_205a40e52526e3ed222f85171d9c05b0);
#
#
#
#
#
#             var marker_ad3ed70197734fd585b54a226516d6b3 = L.marker(
#                 [37.76887083988612,-122.4243784327292],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(map_f14c4e2bac5e3b7e6fefb6aa53a8d7f1);
#
#
#             var popup_89edf5f8a43fa1b447205882242d951b = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_d775604a6fa7cdfd902bb54987fb7b6a = $(&#x27;&lt;div id=&quot;html_d775604a6fa7cdfd902bb54987fb7b6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VEHICLE THEFT&lt;/div&gt;&#x27;)[0];
#                 popup_89edf5f8a43fa1b447205882242d951b.setContent(html_d775604a6fa7cdfd902bb54987fb7b6a);
#
#
#             marker_ad3ed70197734fd585b54a226516d6b3.bindPopup(popup_89edf5f8a43fa1b447205882242d951b);
#
#
#
#
#
#             var marker_5643784df9e5c205b04b23318f961e6b = L.marker(

# %% [markdown]
# ### Visulizing the crimes - 3
#
# In the visulization above, we can see that it looks very messy, one way we can clean it up is to remove the pins and embed the labels of the crimes within the circles

# %%
# let's start again with a clean copy of the map of San Francisco
sf_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# loop through the 100 crimes and add each to the map
for lat, lng, label in zip(df_2016_100.Y, df_2016_100.X, df_2016_100.Category):
    folium.CircleMarker(
        [lat, lng],
        radius=5, # define how big you want the circle markers to be
        color='yellow',
        fill=True,
        popup=label,
        fill_color='red'
    ).add_to(sf_map)

# show map
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_c99b774091150b21c7bad8617466c2e5 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c99b774091150b21c7bad8617466c2e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_c99b774091150b21c7bad8617466c2e5 = L.map(
#                                   &#x27;map_c99b774091150b21c7bad8617466c2e5&#x27;,
#                                   {center: [37.77,-122.42],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_601e43b60596c93c43b2472a642159eb = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_c99b774091150b21c7bad8617466c2e5);
#
#
#             var circle_marker_7ade9e00fdcfcce96f1eafa9f6136aec = L.circleMarker(
#                 [37.70796836450968,-122.46354501681948],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_c99b774091150b21c7bad8617466c2e5);
#
#
#             var popup_c4dfdbc9281a48e321f410704a535810 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_856217e1a5fad92ab3ecccfa1db6e2f7 = $(&#x27;&lt;div id=&quot;html_856217e1a5fad92ab3ecccfa1db6e2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VEHICLE THEFT&lt;/div&gt;&#x27;)[0];
#                 popup_c4dfdbc9281a48e321f410704a535810.setContent(html_856217e1a5fad92ab3ecccfa1db6e2f7);
#
#
#             circle_marker_7ade9e00fdcfcce96f1eafa9f6136aec.bindPopup(popup_c4dfdbc9281a48e321f410704a535810);
#
#
#
#
#             var circle_marker_ba15ef3017f2fccde83e7c9a98be5637 = L.circleMarker(
#                 [37.77563367344303,-122.4124473731242],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_c99b774091150b21c7bad8617466c2e5);
#
#
#             var popup_9f6034c1a3f463d82b41589fe89d6116 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_6b30b548cfc2110fba62fff0b454040a = $(&#x27;&lt;div id=&quot;html_6b30b548cfc2110fba62fff0b454040a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FRAUD&lt;/div&gt;&#x27;)[0];
#                 popup_9f6034c1a3f463d82b41589fe89d6116.setContent(html_6b30b548cfc2110fba62fff0b454040a);
#
#
#             circle_marker_ba15ef3017f2fccde83e7c9a98be5637.bindPopup(popup_9f6034c1a3f463d82b41589fe89d6116);
#
#
#
#
#             var circle_marker_5ad23637c5ed003d257b27eca05874a4 = L.circleMarker(
#                 [37.78413995095941,-122.41095524890568],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_c99b774091150b21c7bad8617466c2e5);
#
#
#             var popup_6f654c5ffe64341eee69cb8b17290656 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_8caabac49d161f70e69350e5c2a134a6 = $(&#x27;&lt;div id=&quot;html_8caabac49d161f70e69350e5c2a134a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;&#x27;)[0];
#                 popup_6f654c5ffe64341eee69cb8b17290656.setContent(html_8caabac49d161f70e69350e5c2a134a6);
#
#
#             circle_marker_5ad23637c5ed003d257b27eca05874a4.bindPopup(popup_6f654c5ffe64341eee69cb8b17290656);
#
#
#
#
#             var circle_marker_b31f2592e729d8b9981f03ee20bbcdd9 = L.circleMarker(
#                 [37.77576787976692,-122.41643219291596],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;yellow&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: t

# %%
from folium import plugins

# let's start again with a clean copy of the map of San Francisco
sf_map = folium.Map(location = [latitude, longitude], zoom_start = 12)

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(sf_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df_2016_100.Y, df_2016_100.X, df_2016_100.Category):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

# display map
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_0df7b06beeba0421234562b75dfb4f59 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0df7b06beeba0421234562b75dfb4f59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_0df7b06beeba0421234562b75dfb4f59 = L.map(
#                                   &#x27;map_0df7b06beeba0421234562b75dfb4f59&#x27;,
#                                   {center: [37.77,-122.42],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_840523f71859303381ff688e55599ac8 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_0df7b06beeba0421234562b75dfb4f59);
#
#
#             var marker_cluster_abc2a530cd2eecf64c8c2617c21f201e = L.markerClusterGroup({
#
#             });
#             map_0df7b06beeba0421234562b75dfb4f59.addLayer(marker_cluster_abc2a530cd2eecf64c8c2617c21f201e);
#
#
#
#             var marker_c40ad9f8d78954cfe7b9b56b3f959e02 = L.marker(
#                 [37.70796836450968,-122.46354501681948],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_abc2a530cd2eecf64c8c2617c21f201e);
#
#
#             var popup_75dd4eccecddce012182ac10ff99b783 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_250875fb57e276cbf04dc462b7e736c1 = $(&#x27;&lt;div id=&quot;html_250875fb57e276cbf04dc462b7e736c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VEHICLE THEFT&lt;/div&gt;&#x27;)[0];
#                 popup_75dd4eccecddce012182ac10ff99b783.setContent(html_250875fb57e276cbf04dc462b7e736c1);
#
#
#             marker_c40ad9f8d78954cfe7b9b56b3f959e02.bindPopup(popup_75dd4eccecddce012182ac10ff99b783);
#
#
#
#
#
#             var marker_58b1cf36098a5384d74cfb12661bc213 = L.marker(
#                 [37.77563367344303,-122.4124473731242],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_abc2a530cd2eecf64c8c2617c21f201e);
#
#
#             var popup_c591648ded5f4657d8c9ea606bfa1a64 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_8e7131f5ad79a0501a6edf20cc8166de = $(&#x27;&lt;div id=&quot;html_8e7131f5ad79a0501a6edf20cc8166de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FRAUD&lt;/div&gt;&#x27;)[0];
#                 popup_c591648ded5f4657d8c9ea606bfa1a64.setContent(html_8e7131f5ad79a0501a6edf20cc8166de);
#
#
#             marker_58b1cf36098a5384d74cfb12661bc213.bindPopup(popup_c591648ded5f4657d8c9ea606bfa1a64);
#
#
#
#
#
#             var marker_e61dda6f40828462700275f7c102906e = L.marker(
#                 [37.78413995095941,-122.41095524890568],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_abc2a530cd2eecf64c8c2617c21f201e);
#
#
#             var popup_104a106383e1dad9315645b263cb5065 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_ac8075415d43c393ffa6bf8bdce5c4df = $(&#x27;&lt;div id=&quot;html_ac8075415d43c393ffa6bf8bdce5c4df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;&#x27;)[0];
#                 popup_104a106383e1dad9315645b263cb5065.setContent(html_ac8075415d43c393ffa6bf8bdce5c4df);
#
#
#             marker_e61dda6f40828462700275f7c102906e.bindPopup(popup_104a106383e1dad9315645b263cb5065);
#
#
#
#
#
#             var marker_aad9b86932370ea60cb19b7102d14b7f = L.marker(
#                 [37.77576787976692,-122.41643219291596],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_abc2a530cd2eecf64c8c2617c21f201e);
#
#
#             var popup_37bfb7e80015dca6aecd1ef09df665b8 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_63af0a89f5083b253af2b9cc7188d803 = $(&#x27;&lt;div id=&quot;html_63af0a89f5083b253af2b9cc7188d803&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;&#x27;)[0];
#                 popup_37bfb7e80015dca6aecd1ef09df665b8.setContent(html_63af0a89f5083b253af2b9cc7188d803);
#
#
#             marker_aad9b86932370ea60cb19b7102d14b7f.bindPopup(popup_37bfb7e80015dca6aecd1ef09df665b8);
#
#
#
#
#
#             var marker_5b9a6d102e3343dcc3462cfe82b78a4b = L.marker(
#                 [37.76887083988612,-122.4243784327292],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
